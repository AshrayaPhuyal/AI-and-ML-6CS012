# %%
import tensorflow as tf
print(tf.keras.__version__)
# Out:
# 3.8.0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from PIL import Image # Import Pillow

# %%
train_dir = "/content/drive/MyDrive/DevanagariHandwrittenDigitDataset/Train"
test_dir = "/content/drive/MyDrive/DevanagariHandwrittenDigitDataset/Test"

# %%
# Define image size
img_height, img_width = 28, 28

# Function to load images and labels
def load_images_from_folder(folder):
    images = []
    labels = []
    class_names = sorted(os.listdir(folder))  # Sorted class names (digit_0, digit_1, ...)
    class_map = {name: i for i, name in enumerate(class_names)}  # Map class names to labels

    for class_name in class_names:
        class_path = os.path.join(folder, class_name)
        label = class_map[class_name]

        for filename in os.listdir(class_path):
            img_path = os.path.join(class_path, filename)
            img = Image.open(img_path).convert("L")  # Convert to grayscale
            img = img.resize((img_width, img_height))  # Resize to (28,28)
            img = np.array(img) / 255.0  # Normalize pixel values to [0,1]

            images.append(img)
            labels.append(label)

    return np.array(images), np.array(labels)

# Load training and testing datasets
x_train, y_train = load_images_from_folder(train_dir)
x_test, y_test = load_images_from_folder(test_dir)

# Reshape images for Keras input
x_train = x_train.reshape(-1, img_height, img_width, 1)  # Shape (num_samples, 28, 28, 1)
x_test = x_test.reshape(-1, img_height, img_width, 1)

# One-hot encode labels
y_train = to_categorical(y_train, num_classes=10)
y_test = to_categorical(y_test, num_classes=10)

# Print dataset shape
print(f"Training set: {x_train.shape}, Labels: {y_train.shape}")
print(f"Testing set: {x_test.shape}, Labels: {y_test.shape}")

# Visualize some images
plt.figure(figsize=(10, 4))
for i in range(10):
    plt.subplot(2, 5, i + 1)
    plt.imshow(x_train[i].reshape(28, 28), cmap="gray")  # Fixed incorrect quote
    plt.title(f"Label: {np.argmax(y_train[i])}")
    plt.axis("off")

plt.show()
# Out:
# Training set: (16779, 28, 28, 1), Labels: (16779, 10)
# Testing set: (3000, 28, 28, 1), Labels: (3000, 10)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.datasets import mnist
# Load the MNIST dataset
# Load MNIST dataset
(X_train, y_train), (X_test, y_test) = mnist.load_data()

#NORMALIZE IMAGES
x_train , x_test = x_train/255.0 , x_test/255.0

# Reshape to match model input shape (28, 28, 1)
x_train = x_train.reshape(-1, 28, 28, 1)
x_test = x_test.reshape(-1, 28, 28, 1)

# One-hot encode labels
y_train = tf.keras.utils.to_categorical(y_train, 10)
y_test = tf.keras.utils.to_categorical(y_test, 10)

# %%
# Model parameters
import tensorflow as tf
from tensorflow import keras
num_classes = 10
input_shape = (28, 28, 1)
def build_functional_model():
# Input layer
  inputs = keras.Input(shape=input_shape)
# Flatten layer
  x = keras.layers.Flatten()(inputs)
# Hidden layers
  x = keras.layers.Dense(64, activation="sigmoid")(x)
  x = keras.layers.Dense(128, activation="sigmoid")(x)
  x = keras.layers.Dense(256, activation="sigmoid")(x)
# Output layer
  outputs = keras.layers.Dense(num_classes, activation="softmax")(x)
# Create model
  model = keras.Model(inputs=inputs, outputs=outputs)
  return model
# Build the model
functional_model = build_functional_model()
functional_model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)           │ (None, 28, 28, 1)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_1 (Flatten)                  │ (None, 784)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 64)                  │          50,240 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 128)                 │           8,320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 256)                 │          33,024 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_7 (Dense)                      │ (None, 10)                  │           2,570 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 94,154 (367.79 KB)
#  Trainable params: 94,154 (367.79 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
functional_model.compile(
optimizer="sgd", # Stochastic Gradient Descent
loss="categorical_crossentropy", # Loss function for multi-class classification
metrics=["accuracy"] # Track accuracy during training
)

# %%
batch_size = 128
epochs = 200
# Callbacks
callbacks = [
keras.callbacks.ModelCheckpoint(filepath="model_at_epoch_{epoch}.keras"),
keras.callbacks.EarlyStopping(monitor="val_loss", patience=200),
]
# Train the model with callbacks and validation split
history = functional_model.fit(
x_train,
y_train,
batch_size=batch_size,
epochs=epochs,
validation_split=0.15,
callbacks=callbacks,
)
# Out:
# Epoch 1/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1024 - loss: 2.3026 - val_accuracy: 0.1196 - val_loss: 2.3006
# Epoch 2/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1146 - loss: 2.3014 - val_accuracy: 0.1053 - val_loss: 2.3030
# Epoch 3/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1044 - loss: 2.3022 - val_accuracy: 0.1196 - val_loss: 2.3009
# Epoch 4/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1093 - loss: 2.3019 - val_accuracy: 0.1196 - val_loss: 2.3007
# Epoch 5/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1063 - loss: 2.3018 - val_accuracy: 0.1196 - val_loss: 2.3010
# Epoch 6/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1137 - loss: 2.3026 - val_accuracy: 0.1033 - val_loss: 2.3033
# Epoch 7/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1101 - loss: 2.3017 - val_accuracy: 0.1196 - val_loss: 2.2999
# Epoch 8/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1075 - loss: 2.3015 - val_accuracy: 0.1196 - val_loss: 2.3021
# Epoch 9/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1094 - loss: 2.3026 - val_accuracy: 0.1196 - val_loss: 2.3025
# Epoch 10/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1056 - loss: 2.3027 - val_accuracy: 0.1033 - val_loss: 2.3021
# Epoch 11/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1131 - loss: 2.3019 - val_accuracy: 0.1033 - val_loss: 2.3017
# Epoch 12/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.1046 - loss: 2.3019 - val_accuracy: 0.1196 - val_loss: 2.3015
# Epoch 13/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.1138 - loss: 2.3014 - val_accuracy: 0.1196 - val_loss: 2.3015
# Epoch 14/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.1097 - loss: 2.3016 - val_accuracy: 0.1196 - val_loss: 2.3002
# Epoch 15/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.1143 - loss: 2.3016 - val_accuracy: 0.1196 - val_loss: 2.3016
# Epoch 16/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1111 - loss: 2.3021 - val_accuracy: 0.1196 - val_loss: 2.3012
# Epoch 17/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1089 - loss: 2.3022 - val_accuracy: 0.1196 - val_loss: 2.3010
# Epoch 18/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1128 - loss: 2.3023 - val_accuracy: 0.1033 - val_loss: 2.3008
# Epoch 19/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1071 - loss: 2.3019 - val_accuracy: 0.1196 - val_loss: 2.3037
# Epoch 20/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1087 - loss: 2.3014 - val_accuracy: 0.1196 - val_loss: 2.3008
# Epoch 21/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1159 - loss: 2.3014 - val_accuracy: 0.1196 - val_loss: 2.3024
# Epoch 22/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1115 - loss: 2.3021 - val_accuracy: 0.1196 - val_loss: 2.3025
# Epoch 23/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1093 - loss: 2.3024 - val_accuracy: 0.1196 - val_loss: 2.3006
# Epoch 24/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1148 - loss: 2.3018 - val_accuracy: 0.1196 - val_loss: 2.3021
# Epoch 25/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1109 - loss: 2.3015 - val_accuracy: 0.1196 - val_loss: 2.3029
# Epoch 26/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1137 - loss: 2.3023 - val_accuracy: 0.1196 - val_loss: 2.3012
# Epoch 27/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1114 - loss: 2.3016 - val_accuracy: 0.1196 - val_loss: 2.3008
# Epoch 28/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1098 - loss: 2.3025 - val_accuracy: 0.1196 - val_loss: 2.3015
# Epoch 29/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1133 - loss: 2.3017 - val_accuracy: 0.1033 - val_loss: 2.3019
# Epoch 30/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.1064 - loss: 2.3017 - val_accuracy: 0.1033 - val_loss: 2.3020
# Epoch 31/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.1083 - loss: 2.3019 - val_accuracy: 0.1196 - val_loss: 2.3018
# Epoch 32/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.1074 - loss: 2.3022 - val_accuracy: 0.1196 - val_loss: 2.3018
# Epoch 33/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1061 - loss: 2.3027 - val_accuracy: 0.1196 - val_loss: 2.3005
# Epoch 34/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1130 - loss: 2.3018 - val_accuracy: 0.1196 - val_loss: 2.3011
# Epoch 35/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1116 - loss: 2.3014 - val_accuracy: 0.1196 - val_loss: 2.3011
# Epoch 36/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1064 - loss: 2.3020 - val_accuracy: 0.1196 - val_loss: 2.3012
# Epoch 37/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1162 - loss: 2.3017 - val_accuracy: 0.1033 - val_loss: 2.3012
# Epoch 38/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1131 - loss: 2.3020 - val_accuracy: 0.1196 - val_loss: 2.3019
# Epoch 39/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1090 - loss: 2.3019 - val_accuracy: 0.1033 - val_loss: 2.3030
# Epoch 40/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1093 - loss: 2.3022 - val_accuracy: 0.1196 - val_loss: 2.3014
# Epoch 41/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1052 - loss: 2.3024 - val_accuracy: 0.1196 - val_loss: 2.3007
# Epoch 42/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1145 - loss: 2.3013 - val_accuracy: 0.1033 - val_loss: 2.3013
# Epoch 43/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.1047 - loss: 2.3025 - val_accuracy: 0.1196 - val_loss: 2.3012
# Epoch 44/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.1135 - loss: 2.3014 - val_accuracy: 0.1033 - val_loss: 2.3014
# Epoch 45/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.1075 - loss: 2.3024 - val_accuracy: 0.1196 - val_loss: 2.3014
# Epoch 46/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1103 - loss: 2.3022 - val_accuracy: 0.1196 - val_loss: 2.3007
# Epoch 47/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1144 - loss: 2.3013 - val_accuracy: 0.1196 - val_loss: 2.3017
# Epoch 48/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1041 - loss: 2.3015 - val_accuracy: 0.1196 - val_loss: 2.3020
# Epoch 49/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1092 - loss: 2.3024 - val_accuracy: 0.1196 - val_loss: 2.3021
# Epoch 50/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1173 - loss: 2.3005 - val_accuracy: 0.1196 - val_loss: 2.3012
# Epoch 51/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1088 - loss: 2.3026 - val_accuracy: 0.1196 - val_loss: 2.3011
# Epoch 52/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1020 - loss: 2.3017 - val_accuracy: 0.1196 - val_loss: 2.3020
# Epoch 53/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1066 - loss: 2.3024 - val_accuracy: 0.1196 - val_loss: 2.3018
# Epoch 54/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1094 - loss: 2.3026 - val_accuracy: 0.1196 - val_loss: 2.3008
# Epoch 55/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1096 - loss: 2.3016 - val_accuracy: 0.1033 - val_loss: 2.3033
# Epoch 56/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1077 - loss: 2.3019 - val_accuracy: 0.1196 - val_loss: 2.3003
# Epoch 57/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1139 - loss: 2.3021 - val_accuracy: 0.1196 - val_loss: 2.3016
# Epoch 58/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1068 - loss: 2.3017 - val_accuracy: 0.1196 - val_loss: 2.3026
# Epoch 59/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.1135 - loss: 2.3020 - val_accuracy: 0.1196 - val_loss: 2.3014
# Epoch 60/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.1091 - loss: 2.3024 - val_accuracy: 0.1196 - val_loss: 2.3014
# Epoch 61/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.1087 - loss: 2.3018 - val_accuracy: 0.1196 - val_loss: 2.3001
# Epoch 62/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1091 - loss: 2.3024 - val_accuracy: 0.1196 - val_loss: 2.3010
# Epoch 63/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1079 - loss: 2.3023 - val_accuracy: 0.1196 - val_loss: 2.3014
# Epoch 64/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1138 - loss: 2.3019 - val_accuracy: 0.1196 - val_loss: 2.3012
# Epoch 65/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1124 - loss: 2.3019 - val_accuracy: 0.1033 - val_loss: 2.3019
# Epoch 66/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1130 - loss: 2.3018 - val_accuracy: 0.1196 - val_loss: 2.3020
# Epoch 67/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1105 - loss: 2.3023 - val_accuracy: 0.1196 - val_loss: 2.3006
# Epoch 68/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1093 - loss: 2.3019 - val_accuracy: 0.1033 - val_loss: 2.3015
# Epoch 69/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1086 - loss: 2.3015 - val_accuracy: 0.1196 - val_loss: 2.3003
# Epoch 70/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1064 - loss: 2.3028 - val_accuracy: 0.1196 - val_loss: 2.3013
# Epoch 71/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1044 - loss: 2.3023 - val_accuracy: 0.1196 - val_loss: 2.3015
# Epoch 72/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1108 - loss: 2.3024 - val_accuracy: 0.0878 - val_loss: 2.3047
# Epoch 73/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.1038 - loss: 2.3025 - val_accuracy: 0.1196 - val_loss: 2.3013
# Epoch 74/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.1136 - loss: 2.3018 - val_accuracy: 0.1033 - val_loss: 2.3016
# Epoch 75/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.1069 - loss: 2.3022 - val_accuracy: 0.1196 - val_loss: 2.3003
# Epoch 76/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1115 - loss: 2.3015 - val_accuracy: 0.1196 - val_loss: 2.3009
# Epoch 77/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1126 - loss: 2.3017 - val_accuracy: 0.1196 - val_loss: 2.3010
# Epoch 78/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.0998 - loss: 2.3027 - val_accuracy: 0.1196 - val_loss: 2.3007
# Epoch 79/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1095 - loss: 2.3023 - val_accuracy: 0.1196 - val_loss: 2.3015
# Epoch 80/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1157 - loss: 2.3013 - val_accuracy: 0.1196 - val_loss: 2.3010
# Epoch 81/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1110 - loss: 2.3025 - val_accuracy: 0.1196 - val_loss: 2.3020
# Epoch 82/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1060 - loss: 2.3036 - val_accuracy: 0.1196 - val_loss: 2.3015
# Epoch 83/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1081 - loss: 2.3027 - val_accuracy: 0.0973 - val_loss: 2.3026
# Epoch 84/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1058 - loss: 2.3024 - val_accuracy: 0.0973 - val_loss: 2.3025
# Epoch 85/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1133 - loss: 2.3020 - val_accuracy: 0.1053 - val_loss: 2.3011
# Epoch 86/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1119 - loss: 2.3013 - val_accuracy: 0.1033 - val_loss: 2.3030
# Epoch 87/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1013 - loss: 2.3038 - val_accuracy: 0.1196 - val_loss: 2.3015
# Epoch 88/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1141 - loss: 2.3016 - val_accuracy: 0.0985 - val_loss: 2.3021
# Epoch 89/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.1071 - loss: 2.3013 - val_accuracy: 0.1196 - val_loss: 2.3011
# Epoch 90/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.1118 - loss: 2.3025 - val_accuracy: 0.1196 - val_loss: 2.3012
# Epoch 91/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.1133 - loss: 2.3028 - val_accuracy: 0.1196 - val_loss: 2.3013
# Epoch 92/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1092 - loss: 2.3024 - val_accuracy: 0.1196 - val_loss: 2.3008
# Epoch 93/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1061 - loss: 2.3032 - val_accuracy: 0.1033 - val_loss: 2.3017
# Epoch 94/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1074 - loss: 2.3017 - val_accuracy: 0.1053 - val_loss: 2.3029
# Epoch 95/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1145 - loss: 2.3013 - val_accuracy: 0.1196 - val_loss: 2.3020
# Epoch 96/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1119 - loss: 2.3020 - val_accuracy: 0.1196 - val_loss: 2.3018
# Epoch 97/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1084 - loss: 2.3024 - val_accuracy: 0.1196 - val_loss: 2.3013
# Epoch 98/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1086 - loss: 2.3026 - val_accuracy: 0.1196 - val_loss: 2.3003
# Epoch 99/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1110 - loss: 2.3023 - val_accuracy: 0.1033 - val_loss: 2.3012
# Epoch 100/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1116 - loss: 2.3012 - val_accuracy: 0.0985 - val_loss: 2.3024
# Epoch 101/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1048 - loss: 2.3023 - val_accuracy: 0.1196 - val_loss: 2.3006
# Epoch 102/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1107 - loss: 2.3021 - val_accuracy: 0.1053 - val_loss: 2.3011
# Epoch 103/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1077 - loss: 2.3021 - val_accuracy: 0.1196 - val_loss: 2.3025
# Epoch 104/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1141 - loss: 2.3021 - val_accuracy: 0.1196 - val_loss: 2.3010
# Epoch 105/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.1094 - loss: 2.3028 - val_accuracy: 0.1196 - val_loss: 2.3012
# Epoch 106/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.1127 - loss: 2.3019 - val_accuracy: 0.1053 - val_loss: 2.3023
# Epoch 107/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.1027 - loss: 2.3022 - val_accuracy: 0.1196 - val_loss: 2.3008
# Epoch 108/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.1129 - loss: 2.3026 - val_accuracy: 0.1033 - val_loss: 2.3022
# Epoch 109/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1097 - loss: 2.3021 - val_accuracy: 0.1196 - val_loss: 2.3008
# Epoch 110/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1044 - loss: 2.3024 - val_accuracy: 0.1053 - val_loss: 2.3027
# Epoch 111/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1077 - loss: 2.3018 - val_accuracy: 0.1196 - val_loss: 2.3016
# Epoch 112/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1039 - loss: 2.3024 - val_accuracy: 0.0985 - val_loss: 2.3030
# Epoch 113/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1071 - loss: 2.3019 - val_accuracy: 0.1033 - val_loss: 2.3018
# Epoch 114/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1079 - loss: 2.3015 - val_accuracy: 0.1196 - val_loss: 2.3006
# Epoch 115/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1070 - loss: 2.3019 - val_accuracy: 0.1033 - val_loss: 2.3023
# Epoch 116/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1125 - loss: 2.3020 - val_accuracy: 0.1196 - val_loss: 2.3012
# Epoch 117/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1060 - loss: 2.3009 - val_accuracy: 0.1196 - val_loss: 2.3028
# Epoch 118/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1114 - loss: 2.3025 - val_accuracy: 0.1196 - val_loss: 2.3007
# Epoch 119/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.1058 - loss: 2.3030 - val_accuracy: 0.1196 - val_loss: 2.3008
# Epoch 120/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.1109 - loss: 2.3019 - val_accuracy: 0.1196 - val_loss: 2.3012
# Epoch 121/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.1100 - loss: 2.3024 - val_accuracy: 0.1196 - val_loss: 2.3017
# Epoch 122/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1152 - loss: 2.3018 - val_accuracy: 0.1196 - val_loss: 2.3011
# Epoch 123/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1105 - loss: 2.3013 - val_accuracy: 0.0985 - val_loss: 2.3023
# Epoch 124/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1002 - loss: 2.3024 - val_accuracy: 0.1196 - val_loss: 2.3014
# Epoch 125/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1137 - loss: 2.3022 - val_accuracy: 0.1196 - val_loss: 2.3021
# Epoch 126/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1103 - loss: 2.3025 - val_accuracy: 0.1196 - val_loss: 2.3015
# Epoch 127/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1106 - loss: 2.3023 - val_accuracy: 0.1196 - val_loss: 2.3010
# Epoch 128/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1105 - loss: 2.3018 - val_accuracy: 0.1196 - val_loss: 2.3016
# Epoch 129/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1081 - loss: 2.3023 - val_accuracy: 0.1196 - val_loss: 2.3005
# Epoch 130/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1090 - loss: 2.3019 - val_accuracy: 0.1033 - val_loss: 2.3023
# Epoch 131/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1054 - loss: 2.3020 - val_accuracy: 0.1196 - val_loss: 2.3012
# Epoch 132/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.1129 - loss: 2.3011 - val_accuracy: 0.1196 - val_loss: 2.3020
# Epoch 133/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.1056 - loss: 2.3029 - val_accuracy: 0.1196 - val_loss: 2.3008
# Epoch 134/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.1039 - loss: 2.3032 - val_accuracy: 0.1196 - val_loss: 2.3018
# Epoch 135/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.1068 - loss: 2.3017 - val_accuracy: 0.1196 - val_loss: 2.2999
# Epoch 136/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1128 - loss: 2.3021 - val_accuracy: 0.1196 - val_loss: 2.3005
# Epoch 137/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1107 - loss: 2.3029 - val_accuracy: 0.1196 - val_loss: 2.3019
# Epoch 138/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1117 - loss: 2.3017 - val_accuracy: 0.0985 - val_loss: 2.3026
# Epoch 139/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1048 - loss: 2.3026 - val_accuracy: 0.1196 - val_loss: 2.3023
# Epoch 140/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1088 - loss: 2.3025 - val_accuracy: 0.1033 - val_loss: 2.3018
# Epoch 141/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1091 - loss: 2.3013 - val_accuracy: 0.1196 - val_loss: 2.3007
# Epoch 142/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1107 - loss: 2.3024 - val_accuracy: 0.1196 - val_loss: 2.3012
# Epoch 143/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1152 - loss: 2.3010 - val_accuracy: 0.1196 - val_loss: 2.3023
# Epoch 144/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1073 - loss: 2.3018 - val_accuracy: 0.1196 - val_loss: 2.3013
# Epoch 145/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1065 - loss: 2.3028 - val_accuracy: 0.1033 - val_loss: 2.3016
# Epoch 146/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1112 - loss: 2.3014 - val_accuracy: 0.1196 - val_loss: 2.3016
# Epoch 147/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.1052 - loss: 2.3024 - val_accuracy: 0.1196 - val_loss: 2.3028
# Epoch 148/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.1132 - loss: 2.3017 - val_accuracy: 0.0965 - val_loss: 2.3029
# Epoch 149/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.1074 - loss: 2.3022 - val_accuracy: 0.0973 - val_loss: 2.3022
# Epoch 150/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.1153 - loss: 2.3013 - val_accuracy: 0.1033 - val_loss: 2.3030
# Epoch 151/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1102 - loss: 2.3020 - val_accuracy: 0.1053 - val_loss: 2.3023
# Epoch 152/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1080 - loss: 2.3023 - val_accuracy: 0.1196 - val_loss: 2.3020
# Epoch 153/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1095 - loss: 2.3031 - val_accuracy: 0.1196 - val_loss: 2.3025
# Epoch 154/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1117 - loss: 2.3024 - val_accuracy: 0.1196 - val_loss: 2.3016
# Epoch 155/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1082 - loss: 2.3023 - val_accuracy: 0.1196 - val_loss: 2.3005
# Epoch 156/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1139 - loss: 2.3022 - val_accuracy: 0.1196 - val_loss: 2.3025
# Epoch 157/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1188 - loss: 2.3010 - val_accuracy: 0.1196 - val_loss: 2.3022
# Epoch 158/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1054 - loss: 2.3022 - val_accuracy: 0.1196 - val_loss: 2.3008
# Epoch 159/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1135 - loss: 2.3017 - val_accuracy: 0.1196 - val_loss: 2.3009
# Epoch 160/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.1061 - loss: 2.3029 - val_accuracy: 0.1196 - val_loss: 2.3009
# Epoch 161/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.1096 - loss: 2.3025 - val_accuracy: 0.0985 - val_loss: 2.3028
# Epoch 162/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.1044 - loss: 2.3028 - val_accuracy: 0.1196 - val_loss: 2.3011
# Epoch 163/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.1104 - loss: 2.3026 - val_accuracy: 0.1196 - val_loss: 2.3012
# Epoch 164/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.1081 - loss: 2.3027 - val_accuracy: 0.1196 - val_loss: 2.3028
# Epoch 165/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1144 - loss: 2.3024 - val_accuracy: 0.1196 - val_loss: 2.3004
# Epoch 166/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1128 - loss: 2.3013 - val_accuracy: 0.1053 - val_loss: 2.3019
# Epoch 167/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1131 - loss: 2.3024 - val_accuracy: 0.1196 - val_loss: 2.3011
# Epoch 168/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1141 - loss: 2.3015 - val_accuracy: 0.1053 - val_loss: 2.3015
# Epoch 169/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1081 - loss: 2.3022 - val_accuracy: 0.1196 - val_loss: 2.3006
# Epoch 170/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1014 - loss: 2.3022 - val_accuracy: 0.1196 - val_loss: 2.3009
# Epoch 171/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1106 - loss: 2.3024 - val_accuracy: 0.1196 - val_loss: 2.3023
# Epoch 172/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1117 - loss: 2.3015 - val_accuracy: 0.1053 - val_loss: 2.3025
# Epoch 173/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1010 - loss: 2.3028 - val_accuracy: 0.1196 - val_loss: 2.3018
# Epoch 174/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1169 - loss: 2.3011 - val_accuracy: 0.1033 - val_loss: 2.3018
# Epoch 175/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1074 - loss: 2.3006 - val_accuracy: 0.1196 - val_loss: 2.3019
# Epoch 176/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.1100 - loss: 2.3028 - val_accuracy: 0.1196 - val_loss: 2.3003
# Epoch 177/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.1065 - loss: 2.3022 - val_accuracy: 0.1196 - val_loss: 2.3013
# Epoch 178/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.1133 - loss: 2.3017 - val_accuracy: 0.1196 - val_loss: 2.3014
# Epoch 179/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1147 - loss: 2.3017 - val_accuracy: 0.1033 - val_loss: 2.3019
# Epoch 180/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1117 - loss: 2.3021 - val_accuracy: 0.1033 - val_loss: 2.3022
# Epoch 181/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1053 - loss: 2.3020 - val_accuracy: 0.1196 - val_loss: 2.3022
# Epoch 182/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1141 - loss: 2.3023 - val_accuracy: 0.1196 - val_loss: 2.3018
# Epoch 183/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1094 - loss: 2.3025 - val_accuracy: 0.1196 - val_loss: 2.3015
# Epoch 184/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1069 - loss: 2.3024 - val_accuracy: 0.1196 - val_loss: 2.3016
# Epoch 185/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1180 - loss: 2.3010 - val_accuracy: 0.1033 - val_loss: 2.3036
# Epoch 186/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1067 - loss: 2.3023 - val_accuracy: 0.1033 - val_loss: 2.3015
# Epoch 187/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1149 - loss: 2.3016 - val_accuracy: 0.0985 - val_loss: 2.3011
# Epoch 188/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1103 - loss: 2.3016 - val_accuracy: 0.1196 - val_loss: 2.3005
# Epoch 189/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.1151 - loss: 2.3013 - val_accuracy: 0.1196 - val_loss: 2.3007
# Epoch 190/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.1126 - loss: 2.3016 - val_accuracy: 0.1033 - val_loss: 2.3015
# Epoch 191/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.1134 - loss: 2.3011 - val_accuracy: 0.1033 - val_loss: 2.3013
# Epoch 192/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.1047 - loss: 2.3026 - val_accuracy: 0.1196 - val_loss: 2.3013
# Epoch 193/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.1088 - loss: 2.3022 - val_accuracy: 0.1196 - val_loss: 2.3026
# Epoch 194/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1143 - loss: 2.3012 - val_accuracy: 0.1196 - val_loss: 2.3007
# Epoch 195/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1108 - loss: 2.3027 - val_accuracy: 0.1196 - val_loss: 2.3008
# Epoch 196/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1057 - loss: 2.3027 - val_accuracy: 0.1196 - val_loss: 2.3008
# Epoch 197/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1135 - loss: 2.3004 - val_accuracy: 0.1196 - val_loss: 2.3013
# Epoch 198/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1092 - loss: 2.3010 - val_accuracy: 0.1033 - val_loss: 2.3005
# Epoch 199/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1014 - loss: 2.3010 - val_accuracy: 0.1196 - val_loss: 2.3009
# Epoch 200/200
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1086 - loss: 2.3029 - val_accuracy: 0.1196 - val_loss: 2.3011

# %%
train_loss = history.history['loss']
val_loss = history.history['val_loss']
# Extracting training and validation accuracy (if metrics were specified)
train_acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
# Plotting training and validation loss
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(range(1, len(train_loss) + 1), train_loss, label='Training Loss', color='blue')
plt.plot(range(1, len(val_loss) + 1), val_loss, label='Validation Loss', color='orange')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
# Plotting training and validation accuracy
plt.subplot(1, 2, 2)
plt.plot(range(1, len(train_acc) + 1), train_acc, label='Training Accuracy', color='blue')
plt.plot(range(1, len(val_acc) + 1), val_acc, label='Validation Accuracy', color='orange')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Predict on test data
predictions = functional_model.predict(x_test)
# Convert predictions from probabilities to digit labels
predicted_labels = np.argmax(predictions, axis=1)
# Check the first prediction
print(f"Predicted label for first image: {predicted_labels[0]}")
print(f"True label for first image: {np.argmax(y_test[0])}")
# Out:
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Predicted label for first image: 1
# True label for first image: 7

# %%
functional_model.save('AshrayaPhuyal.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
loaded_model = tf.keras.models.load_model('AshrayaPhuyal.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
